# %% [markdown]
# <a href="https://colab.research.google.com/github/chandana1985/DSA0404-Fundamentals-of-Data-Science/blob/main/Hands_on_Data_summarization%2CData_distribution_and_outlier_treatment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Upload Dataset
from google.colab import files
uploaded = files.upload()

# Import Library
import pandas as pd

# Read Dataset
df = pd.read_csv("Employee.csv")

# Display First 5 Rows
print("First 5 Rows:")
print(df.head())

# Number of Rows and Columns
print("\nNumber of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])

# Data Types
print("\nData Types:")
print(df.dtypes)

# Missing Values
print("\nMissing Values:")
print(df.isnull().sum())

# Statistical Summary
print("\nStatistical Summary:")
print(df.describe(include='all'))
# Out:
#      <input type="file" id="files-fd357baa-0e74-4a30-a93d-1b24fa8ee0f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd357baa-0e74-4a30-a93d-1b24fa8ee0f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Upload Dataset
from google.colab import files
uploaded = files.upload()

# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt

# Read Dataset
df = pd.read_csv("StudentsPerformance.csv")

# Display First Five Rows
print("First Five Rows:")
print(df.head())

# Create Grade Column from Math Score
def grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"

df["Grade"] = df["math score"].apply(grade)

# Frequency Distribution
grade_count = df["Grade"].value_counts().sort_index()

print("\nFrequency Distribution of Grades:")
print(grade_count)

# Plot Bar Chart
plt.figure(figsize=(6,4))
plt.bar(grade_count.index, grade_count.values)

plt.title("Students Grade Distribution")
plt.xlabel("Grades")
plt.ylabel("Frequency")

plt.show()
# Out:
#      <input type="file" id="files-c84029bd-00d7-4be1-bd61-3e6d98ba18f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c84029bd-00d7-4be1-bd61-3e6d98ba18f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("kc_house_data.csv")

print(df.head())

plt.figure(figsize=(8,5))
plt.hist(df["price"], bins=20, edgecolor="black")

plt.title("Histogram of House Prices")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.grid()

plt.show()

print("Skewness:", df["price"].skew())
# Out:
#      <input type="file" id="files-36b84d92-6dea-483e-9910-4ee4d0483bb9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36b84d92-6dea-483e-9910-4ee4d0483bb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Salary_dataset.csv")

print(df.head())

plt.figure(figsize=(6,5))
plt.boxplot(df["Salary"])

plt.title("Salary Box Plot")
plt.ylabel("Salary")

plt.show()
# Out:
#      <input type="file" id="files-3cbeaf29-34db-4e71-be25-b02bff6980ae" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3cbeaf29-34db-4e71-be25-b02bff6980ae">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd

df = pd.read_csv("StudentsPerformance.csv")

Q1 = df["math score"].quantile(0.25)
Q3 = df["math score"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["math score"] < lower) | (df["math score"] > upper)]

print("Outliers")
print(outliers)
# Out:
#      <input type="file" id="files-fca0e9b9-b269-49ee-8489-1803161b31e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fca0e9b9-b269-49ee-8489-1803161b31e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd

df = pd.read_csv("SampleSuperstore.csv", encoding='latin1')

Q1 = df["Sales"].quantile(0.25)
Q3 = df["Sales"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

clean = df[(df["Sales"] >= lower) & (df["Sales"] <= upper)]

print(clean.head())

print("\nOriginal Rows:", len(df))
print("Rows After Removing Outliers:", len(clean))
# Out:
#      <input type="file" id="files-e2456e50-c050-46d3-af88-98a00d386c1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e2456e50-c050-46d3-af88-98a00d386c1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("SampleSuperstore.csv", encoding='latin1')

Q1 = df["Sales"].quantile(0.25)
Q3 = df["Sales"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

clean = df[(df["Sales"] >= lower) & (df["Sales"] <= upper)]

plt.hist(df["Sales"], bins=20)
plt.title("Before Removing Outliers")
plt.show()

plt.boxplot(df["Sales"])
plt.title("Before Removing Outliers")
plt.show()

plt.hist(clean["Sales"], bins=20)
plt.title("After Removing Outliers")
plt.show()

plt.boxplot(clean["Sales"])
plt.title("After Removing Outliers")
plt.show()
# Out:
#      <input type="file" id="files-5029d76f-77fa-4497-b245-3a7720489ce6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5029d76f-77fa-4497-b245-3a7720489ce6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt

# Upload Titanic Dataset
uploaded = files.upload()

# Read Dataset
df = pd.read_csv("Titanic-Dataset.csv")

# Dataset Information
print("Dataset Information")
print(df.info())

# First 5 Rows
print("\nFirst Five Rows")
print(df.head())

# Missing Values
print("\nMissing Values")
print(df.isnull().sum())

# Descriptive Statistics
print("\nDescriptive Statistics")
print(df.describe())

# Histograms
df.hist(figsize=(12,8))
plt.show()

# Box Plot for Age
plt.figure(figsize=(5,4))
plt.boxplot(df["Age"].dropna())
plt.title("Box Plot of Age")
plt.show()

# Box Plot for Fare
plt.figure(figsize=(5,4))
plt.boxplot(df["Fare"].dropna())
plt.title("Box Plot of Fare")
plt.show()

# Detect Outliers using IQR (Fare)
Q1 = df["Fare"].quantile(0.25)
Q3 = df["Fare"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df["Fare"] < lower) | (df["Fare"] > upper)]

print("\nOutliers:")
print(outliers)

# Remove Outliers
clean_df = df[(df["Fare"] >= lower) & (df["Fare"] <= upper)]

print("\nOriginal Rows:", len(df))
print("Rows After Removing Outliers:", len(clean_df))

# Save Cleaned Dataset
clean_df.to_csv("Titanic_Cleaned.csv", index=False)

print("\nCleaned dataset saved successfully.")
# Out:
#      <input type="file" id="files-08b426c6-0894-41af-a8a8-5392f095e855" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08b426c6-0894-41af-a8a8-5392f095e855">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
